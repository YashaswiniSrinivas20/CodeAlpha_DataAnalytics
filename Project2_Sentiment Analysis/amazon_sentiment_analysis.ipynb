# %%
# Amazon Reviews Sentiment Analysis
# Author: Your Name
# Internship: CodeAlpha - Data Analytics

# ==============================
# 1. Import Libraries
# ==============================
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
import seaborn as sns


# ==============================
# 2. Load Dataset
# ==============================
df = pd.read_csv("amazon_reviews_sample.csv")
print(df.head())

# ==============================
# 3. Sentiment Analysis Function
# ==============================
def get_sentiment(text):
    analysis = TextBlob(str(text))
    if analysis.sentiment.polarity > 0:
        return "Positive"
    elif analysis.sentiment.polarity < 0:
        return "Negative"
    else:
        return "Neutral"

df["Sentiment"] = df["reviewText"].apply(get_sentiment)
print(df.head())

# ==============================
# 4. Visualization
# ==============================
sns.countplot(x=df["Sentiment"], palette="Set2")
plt.title("Sentiment Distribution of Amazon Reviews")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()

# ==============================
# 5. Save Clean Dataset
# ==============================
df.to_csv("amazon_reviews_with_sentiment.csv", index=False)
# Out:
#                                           reviewText
# 0  This product is amazing, really loved the qual...
# 1         Worst purchase ever. Totally disappointed.
# 2     It works fine, nothing extraordinary but okay.
# 3    Excellent value for money, highly recommend it!
# 4   Terrible packaging, item was damaged on arrival.
#                                           reviewText Sentiment
# 0  This product is amazing, really loved the qual...  Positive
# 1         Worst purchase ever. Totally disappointed.  Negative
# 2     It works fine, nothing extraordinary but okay.  Positive
# 3    Excellent value for money, highly recommend it!  Positive
# 4   Terrible packaging, item was damaged on arrival.  Negative
